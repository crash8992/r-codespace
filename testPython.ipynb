# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 20, 30, 40, 50])
print("Media:", x.mean())
print("Desviación estándar:", x.std())

plt.plot(x, marker="o", color="red")
plt.title("Gráfico de prueba en Python")
plt.show()
# Out:
# Media: 30.0
# Desviación estándar: 14.142135623730951
